# %% [markdown]
# The point of this script is to achieve the following:
# - Get a list of all the .csv files that relate to the psychopy datafile
# - Analyse the data so we just have the key datapoints for each participant
# - loop this round to do all the datapoints
# - put it all into a .csv or .xlsx file to horizontally concatenate with the qualtrics dataset

# %%
import os
import numpy as np
import pandas as pd
import glob

# %%
os.getcwd()
# Out:
# '/Users/jackcrosby/Desktop/ToT_Study_1/data'

# %%
os.chdir('/Users/jackcrosby/Desktop/ToT_Study_1/data')
os.getcwd()
# Out:
# '/Users/jackcrosby/Desktop/ToT_Study_1/data'

# %%
csvlist = glob.glob('*.csv')
print(csvlist)
# Out:
# ['_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1427_1.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1622.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1427.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1546.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1552.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1426.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1430.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1550.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1330.csv', '_Robyn_PsychoPy_Positive_Music_2022_Jun_09_1443.csv']

# %%
print(csvlist[1])
# Out:
# _Robyn_PsychoPy_Positive_Music_2022_Jun_09_1622.csv

# %%
df = pd.read_csv(csvlist[4])
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999
display(df)
# Out:
#            Img SayAloud  trials.thisRepN  trials.thisTrialN  trials.thisN  \
# 0          NaN      NaN              NaN                NaN           NaN
# 1          NaN      NaN              NaN                NaN           NaN
# 2          NaN      NaN              NaN                NaN           NaN
# 3  AF27NES.JPG        d              0.0                0.0           0.0
# 4  AF22NES.JPG        f              0.0                1.0           1.0
# 5  AF32NES.JPG        w              0.0                2.0           2.0
# 6  AF23NES.JPG        q              0.0                3.0           3.0
#
#    trials.thisIndex  text.started text.stopped key_resp.keys  key_resp.rt  \
# 0               NaN      7.129268         None         space     1.320444
# 1               NaN           NaN          NaN           NaN          NaN
# 2               NaN           NaN          NaN           NaN          NaN
# 3              13.0           NaN          NaN           NaN          NaN
# ...

# %%
df2 = df[['Img', 'SayAloud', 'knowbutton.started', 'knowbutton.stopped', 'knowbutton.numClicks', 'ToTButton.numClicks', 'Dontknowbutton.numClicks', 'textbox.text', 'textbox.started', 'textbox.stopped', 'frameRate']]

# %%
display(df2)
# Out:
#            Img SayAloud  knowbutton.started knowbutton.stopped  \
# 0          NaN      NaN                 NaN                NaN
# 1          NaN      NaN                 NaN                NaN
# 2          NaN      NaN                 NaN                NaN
# 3  AF27NES.JPG        d           88.628681               None
# 4  AF22NES.JPG        f           99.275683               None
# 5  AF32NES.JPG        w          114.715275               None
# 6  AF23NES.JPG        q          122.416849               None
#
#    knowbutton.numClicks  ToTButton.numClicks  Dontknowbutton.numClicks  \
# 0                   NaN                  NaN                       NaN
# 1                   NaN                  NaN                       NaN
# 2                   NaN                  NaN                       NaN
# 3                   1.0                  0.0                       0.0
# 4                   1.0                  1.0                       0.0
# ...

# %%
df2['textbox.text'].T
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3     ojihgcfghjk
# 4    kjyfkhfdhjkf
# 5             ytf
# 6            kuyf
# Name: textbox.text, dtype: object

# %%
df2['Button.RT'] = df['knowbutton.started'] - df['textbox.started']
# Out:
# /var/folders/wr/9s_983rd7219064h8l10ycz40000gn/T/ipykernel_63623/2686519153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Button.RT'] = df['knowbutton.started'] - df['textbox.started']

# %%
display(df2)
df.to_csv(str('urmum'+csvlist[4]))
# Out:
#            Img SayAloud  knowbutton.started knowbutton.stopped  \
# 0          NaN      NaN                 NaN                NaN
# 1          NaN      NaN                 NaN                NaN
# 2          NaN      NaN                 NaN                NaN
# 3  AF27NES.JPG        d           88.628681               None
# 4  AF22NES.JPG        f           99.275683               None
# 5  AF32NES.JPG        w          114.715275               None
# 6  AF23NES.JPG        q          122.416849               None
#
#    knowbutton.numClicks  ToTButton.numClicks  Dontknowbutton.numClicks  \
# 0                   NaN                  NaN                       NaN
# 1                   NaN                  NaN                       NaN
# 2                   NaN                  NaN                       NaN
# 3                   1.0                  0.0                       0.0
# 4                   1.0                  1.0                       0.0
# ...
